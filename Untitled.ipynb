# %%
# !pip install python-pptx
from pptx import Presentation

prs = Presentation()

slides = [
    ("Image Deblurring and Object Detection using Wiener Filter and YOLOv8n Model",
     ["Aakash Sai Ganeshbabu"]),
    
    ("Problem",
     ["Blur reduces image quality",
      "Blur affects object detection performance",
      "Goal: test whether deblurring improves detection"]),
    
    ("Dataset",
     ["COCO 2017 + COCOBlur",
      "300-image subset",
      "Train: 180, Val: 60, Test: 60"]),
    
    ("Deblurring Methods",
     ["Gaussian filtering (baseline)",
      "Wiener deconvolution",
      "Metrics: PSNR and SSIM"]),
    
    ("Deblurring Results",
     ["Gaussian: PSNR 23.009, SSIM 0.650",
      "Wiener: PSNR 23.147, SSIM 0.663",
      "Wiener slightly improved restoration metrics"]),
    
    ("Pretrained Detection Results",
     ["Blurred: 5.0 detections, 0.471 confidence",
      "Gaussian: 5.0 detections, 0.494 confidence",
      "Wiener: 4.0 detections, 0.413 confidence"]),
    
    ("Training Pipeline",
     ["Converted COCO annotations to YOLO labels",
      "Initial training failed due to wrong dataset structure",
      "Fixed using standard YOLO images/labels layout"]),
    
    ("Final Trained-Model Results",
     ["Blurred: 30.983 detections, 0.108 confidence",
      "Deblurred: 23.217 detections, 0.113 confidence",
      "Original: 58.15 detections, 0.161 confidence"]),
    
    ("Critical Analysis",
     ["Wiener improved PSNR/SSIM slightly",
      "Deblurred images did not outperform blurred images",
      "Original images remained strongest"]),
    
    ("Conclusion",
     ["Better restoration quality did not guarantee better detection",
      "Original sharp images performed best",
      "Future work: deep learning deblurring and larger datasets"])
]

for title, bullets in slides:
    slide = prs.slides.add_slide(prs.slide_layouts[1])
    slide.shapes.title.text = title
    tf = slide.shapes.placeholders[1].text_frame
    tf.clear()
    for i, bullet in enumerate(bullets):
        if i == 0:
            tf.text = bullet
        else:
            p = tf.add_paragraph()
            p.text = bullet

prs.save("presentation.pptx")
print("Saved presentation.pptx")
"PDF/report note

The easiest path:

paste the report text into Word or Google Docs
add your final images from results/final_examples
export as PDF
Where to paste PPT code for free

Use:

https://colab.research.google.com

Paste the PPT code there, run it, and download presentation.pptx.

Copyright / plagiarism / AI safety

From everything youve shown here:

Safe
Standard OpenCV / NumPy / Ultralytics usage
Your own results and metrics
Your own dataset preparation and debugging process
AI-assisted writing/debugging with disclosure
You must mention
COCO dataset
COCOBlur dataset
Ultralytics YOLOv8
AI assistance statement
I do not currently see
direct copyrighted code copied from a proprietary source
prohibited song lyrics / book excerpts / copyrighted long text
Best protection

Include this exactly in your report or README:

Generative AI tools were used for generating ideas and insights, debugging support,grammer for documentation drafting. All generated outputs were manually reviewed, modified, and tested before submission.

Final note

Your final trained-model numbers are now:

Blurred: 30.983 / 0.108
Deblurred: 23.217 / 0.113
Original: 58.15 / 0.161

These are the final results you should present.
# Out:
#   Cell In[7], line 70
#     PDF/report note
#                ^
# SyntaxError: invalid syntax
